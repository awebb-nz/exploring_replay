# %%
import numpy as np
import matplotlib.pyplot as plt
import os, pickle
from agent_replay import Agent 
from utils import plot_maze, load_env

# %%
env_file_path  = '/home/georgy/Documents/Dayan_lab/PhD/bandits/maze/code/mazes/tolman1.txt'
env_config     = load_env(env_file_path)

# --- Specify agent parameters ---
ag_config = {
    'alpha'          : 1,          # online learning rate
    'alpha_r'        : 1,          # offline learning rate
    'online_beta'    : 10,          # inverse temperature
    'gain_beta'      : 50,
    'need_beta'      : 5,
    'policy_type'    : 'softmax',
    'gamma'          : 0.85,        # discount
    'horizon'        : 2,          # minus 1
    'xi'             : 1e-3,       # EVB threshold
    'num_sims'       : 1000,       # number of MC simulations

    'phi'            : 0.5,
    'kappa'          : 0.5,
}

agent    = Agent(*[ag_config, env_config])

# %%
Q_MB     = agent._solve_mb(1e-5)

# %%
fig = plt.figure(figsize=(6, 5))
ax  = fig.add_axes([0, 0, 1, 1])
plot_maze(ax, Q_MB, agent)

# %%
agent.state = 38
agent.Q     = Q_MB
agent.M     = 0.5
Q_history, gain_history, need_history = agent._replay()
# Out:
# Replay [<14, 0>, 0] horizon 0, q_old: 0.10, q_new: 0.42, evb: 0.01510
# Replay [<20, 0>, 0] horizon 0, q_old: 0.10, q_new: 0.36, evb: 0.03897
# Replay [<26, 0>, 0] horizon 0, q_old: 0.12, q_new: 0.31, evb: 0.04837
# Replay [<32, 0>, 0] horizon 0, q_old: 0.14, q_new: 0.26, evb: 0.11507
# Replay [<31, 0>, 3] horizon 0, q_old: 0.17, q_new: 0.22, evb: 0.00254
# Replay [<19, 0>, 3] horizon 0, q_old: 0.12, q_new: 0.31, evb: 0.00232
# Replay [<18, 0>, 3] horizon 0, q_old: 0.10, q_new: 0.26, evb: 0.00269
# Replay [<24, 0>, 0] horizon 0, q_old: 0.09, q_new: 0.22, evb: 0.00405
# Replay [<30, 0>, 0] horizon 0, q_old: 0.10, q_new: 0.19, evb: 0.00377

# %%
fig = plt.figure(figsize=(6, 5))
ax  = fig.add_axes([0, 0, 1, 1])
plot_maze(ax, agent.Q, agent)

# %%
Q = agent.Q.copy()
Q[14, 0] = 0
agent.Q = Q

# %%
fig = plt.figure(figsize=(6, 5))
ax  = fig.add_axes([0, 0, 1, 1])
plot_maze(ax, agent.Q, agent)

# %%
agent.beta = 50

# %%
Q          = agent.Q.copy()
q_before   = agent.Q[20, :].copy()

q_after    = agent.Q[20, :].copy()
q_after[0] = q_after[0] + 1*(0 + 0.85*np.nanmax(Q[14, :]) - q_after[0])

# %%
q_before
# Out:
# array([0.36125   , 0.14224176, 0.10276967,        nan])

# %%
q_after
# Out:
# array([0.10276967, 0.14224176, 0.10276967,        nan])

# %%
agent._compute_gain(q_before, q_after)
# Out:
# 3.0887304908057692e-02

# %%
Q          = agent.Q.copy()
q_before   = agent.Q[14, :].copy()

q_after    = agent.Q[14, :].copy()
q_after[1] = q_after[1] + 1*(0 + 0.85*np.nanmax(Q[20, :]) - q_after[1])

# %%
q_before
# Out:
# array([0.        , 0.12090549,        nan,        nan])

# %%
q_after
# Out:
# array([0.       , 0.3070625,       nan,       nan])

# %%
agent._compute_gain(q_before, q_after)
# Out:
# 7.256550426082227e-04

# %%
agent.state = 14
agent.M     = 0.0
Q_history, gain_history, need_history = agent._replay()
# Out:
# Replay [<20, 0>, 0] horizon 0, q_old: 0.36, q_new: 0.10, evb: 0.04688
# Replay [<20, 0>, 2] horizon 0, q_old: 0.10, q_new: 0.26, evb: 0.16170
# Replay [<14, 0>, 1] horizon 0, q_old: 0.12, q_new: 0.22, evb: 0.00163

# %%
fig = plt.figure(figsize=(6, 5))
ax  = fig.add_axes([0, 0, 1, 1])
plot_maze(ax, agent.Q, agent)
