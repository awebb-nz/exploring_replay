# %%
from environment import Environment
from utils import plot_env, load_env, plot_maze
import numpy as np
import matplotlib.pyplot as plt
import os
import ast

# %%
env_config_file = os.path.join('/home/georgy/Documents/Dayan_lab/PhD/bandits/maze/code/mazes', 'tolman1.txt')
env_config      = load_env(env_config_file)
env             = Environment(**env_config)

fig = plt.figure(figsize=(4, 4))
ax  = fig.add_axes([0, 0, 1, 1])
plot_env(ax, env)

# %%
env_config_file = os.path.join('/home/georgy/Documents/Dayan_lab/PhD/bandits/maze/code/mazes', 'tolman2.txt')
env_config      = load_env(env_config_file)
env             = Environment(**env_config)

fig = plt.figure(figsize=(4, 4))
ax  = fig.add_axes([0, 0, 1, 1])
plot_env(ax, env)

# %%
env_config_file = os.path.join('/home/georgy/Documents/Dayan_lab/PhD/bandits/maze/code/mazes', 'u.txt')
env_config      = load_env(env_config_file)
env             = Environment(**env_config)

fig = plt.figure(figsize=(4, 4))
ax  = fig.add_axes([0, 0, 1, 1])
plot_env(ax, env)

# plt.savefig('/home/georgy/Documents/Dayan_lab/PhD/bandits/maze/data/rldm_poster/umaze.svg', transparent=True)

# %%
fig = plt.figure(figsize=(5, 4))
ax  = fig.add_axes([0, 0, 1, 1])
Q   = np.zeros((4, 4))
Q[0, 0] = np.nan
Q[0, 2] = np.nan
Q[2, 2] = np.nan
Q[2, 1] = np.nan
Q[3, 1] = np.nan
Q[3, 3] = np.nan
plot_maze(ax, Q, env)
# plt.savefig('/home/georgy/Documents/Dayan_lab/PhD/bandits/maze/data/rldm_poster/umaze.svg', transparent=True)
